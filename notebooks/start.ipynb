# %%
import nflreadpy as nfl
import pandas as pd 
import numpy as np

# %%
schedules = nfl.load_schedules([2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025])

# %%
type(schedules)
# Out:
# polars.dataframe.frame.DataFrame

# %%
# !pip install pyarrow
# Out:
# ...
#    ---------------------------------------- 0.0/27.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/27.9 MB ? eta -:--:--
#     --------------------------------------- 0.5/27.9 MB 2.1 MB/s eta 0:00:13
#    - -------------------------------------- 1.0/27.9 MB 2.3 MB/s eta 0:00:12
#    -- ------------------------------------- 1.6/27.9 MB 2.6 MB/s eta 0:00:10
#    --- ------------------------------------ 2.4/27.9 MB 2.8 MB/s eta 0:00:10
#    ---- ----------------------------------- 2.9/27.9 MB 2.9 MB/s eta 0:00:09
#    ----- ---------------------------------- 3.7/27.9 MB 3.0 MB/s eta 0:00:09
#    ----- ---------------------------------- 3.9/27.9 MB 3.1 MB/s eta 0:00:08
#    ------ --------------------------------- 4.7/27.9 MB 2.9 MB/s eta 0:00:09
#    -------- ------------------------------- 5.8/27.9 MB 3.1 MB/s eta 0:00:08
#    --------- ------------------------------ 6.6/27.9 MB 3.3 MB/s eta 0:00:07
# ...

# %%
schedules = schedules.to_pandas()

# %%
schedules.head()
# Out:
#            game_id  season game_type  week     gameday   weekday gametime  \
# 0  2016_01_CAR_DEN    2016       REG     1  2016-09-08  Thursday    20:30
# 1   2016_01_TB_ATL    2016       REG     1  2016-09-11    Sunday    13:00
# 2  2016_01_BUF_BAL    2016       REG     1  2016-09-11    Sunday    13:00
# 3  2016_01_CHI_HOU    2016       REG     1  2016-09-11    Sunday    13:00
# 4   2016_01_GB_JAX    2016       REG     1  2016-09-11    Sunday    13:00
#
#   away_team  away_score home_team  ...  wind  away_qb_id  home_qb_id  \
# 0       CAR          20       DEN  ...  10.0  00-0027939  00-0032156
# 1        TB          31       ATL  ...   NaN  00-0031503  00-0026143
# 2       BUF           7       BAL  ...   8.0  00-0028118  00-0026158
# 3       CHI          14       HOU  ...   NaN  00-0024226  00-0029682
# 4        GB          27       JAX  ...   3.0  00-0023459  00-0031407
#
#      away_qb_name    home_qb_name     away_coach     home_coach  \
# ...

# %%
schedules.season.unique()
# Out:
# array([2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025],
#       dtype=int32)

# %%
schedules.to_csv('../datasets/NFL_schedule.csv', index=False)
